# %% [markdown]
# # Loading and Modeling Mail Data

# %%
import mailbox
import pandas as pd

# Define the path to your mbox file
mbox_file_path = 'All mail Including Spam and Trash.mbox'

# Function to parse the mbox file and return a list of dictionaries
def load_mbox_to_list(mbox_file_path):
    mbox = mailbox.mbox(mbox_file_path)
    messages = []
    for message in mbox:
        msg_data = {
            'Subject': message['subject'],
            'From': message['from'],
            'To': message['to'],
            'Date': message['date'],
            'Message_ID': message['message-id'],
            'Body': message.get_payload(),
        }
        messages.append(msg_data)
    return messages

# Load mbox data into a list of dictionaries
email_data = load_mbox_to_list(mbox_file_path)


# Create a Pandas DataFrame from the list of dictionaries
df = pd.DataFrame(email_data)

# Filtering spam emails
spam_keywords = ['spam', 'viagra', 'lottery']
spam_filter = df['Subject'].str.contains('|'.join(spam_keywords), case=False, na=False)
spam_emails = df[spam_filter]
print("---------------- Spam Emails:")
print(spam_emails)

# Count the number of emails from each sender
sender_counts = df['From'].value_counts()
print("\n ---------------- Sender Counts:")
print(sender_counts)

# Count the number of emails containing specific keywords (e.g., "meeting")
meeting_keywords = ['couresa', 'linkedIn']
meeting_filter = df['Subject'].str.contains('|'.join(meeting_keywords), case=False, na=False)
meeting_emails = df[meeting_filter]
print("\n---------------- Coursea and  Emails:")
print(meeting_emails)
# Out:
# ---------------- Spam Emails:
# Empty DataFrame
# Columns: [Subject, From, To, Date, Message_ID, Body]
# Index: []
#
#  ---------------- Sender Counts:
# From
# LinkedIn Job Alerts <jobalerts-noreply@linkedin.com>                                123
# Ei Ei <eiei.cumyeik@gmail.com>                                                       40
# "thanbula.21" <thanbula.21@gmail.com>                                                31
# "Ee.lay" <eiei.cumyeik@gmail.com>                                                    28
# "yokelzinwai@gmail.com" <yokelzinwai@gmail.com>                                      23
#                                                                                    ...
# "chatdoelay@gmail.com" <chatdoelay@gmail.com>                                         1
# "Scrum Master Certification: Scrum Methodologies" <no-reply@t.mail.coursera.org>      1
# "Introduction to Scrum Master Training" <no-reply@t.mail.coursera.org>                1
# "myatkay2010@gmail.com" <myatkay2010@gmail.com>                                       1
# aye aung <ayeaung750@gmail.com>                                                       1
# Name: count, Length: 235, dtype: int64
#
# ---------------- Meeting Emails:
#                                                Subject  \
# 10   si thu hlaing and others share their thoughts ...
# 86   Ei Thet and others share their thoughts on Lin...
# 100  JobNet Myanmar and others share their thoughts...
# 233   Add Kyaw Zay Ya Lin Tun to your LinkedIn network
# 281  Ei Thet and others share their thoughts on Lin...
# 296  Clinton Health Access Initiative, Inc. and oth...
# 611  KBZ Bank and others share their thoughts on Li...
# 615  =?UTF-8?Q?Ei_Thet_shared_a_post:_Dear_LinkedIn...
# 713                Ei, land your next job on LinkedIn.
# 723  Ei Thet and others share their thoughts on Lin...
# 770  Ei Thet and others share their thoughts on Lin...
#
#                                                   From  \
# 10             LinkedIn <updates-noreply@linkedin.com>
# 86             LinkedIn <updates-noreply@linkedin.com>
# 100            LinkedIn <updates-noreply@linkedin.com>
# 233           LinkedIn <messages-noreply@linkedin.com>
# 281            LinkedIn <updates-noreply@linkedin.com>
# 296            LinkedIn <updates-noreply@linkedin.com>
# 611            LinkedIn <updates-noreply@linkedin.com>
# 615      LinkedIn <notifications-noreply@linkedin.com>
# 713  =?UTF-8?B?TGlua2VkSW4=?= <linkedin@e.linkedin....
# 723            LinkedIn <updates-noreply@linkedin.com>
# 770            LinkedIn <updates-noreply@linkedin.com>
#
#                                  To                                   Date  \
# 10   Ei Ei <eiei.cumyeik@gmail.com>  Fri, 27 Oct 2023 12:36:43 +0000 (UTC)
# 86   Ei Ei <eiei.cumyeik@gmail.com>   Mon, 9 Oct 2023 12:37:43 +0000 (UTC)
# 100  Ei Ei <eiei.cumyeik@gmail.com>  Wed, 18 Oct 2023 12:36:42 +0000 (UTC)
# 233  Ei Ei <eiei.cumyeik@gmail.com>  Mon, 30 Oct 2023 12:36:43 +0000 (UTC)
# 281  Ei Ei <eiei.cumyeik@gmail.com>   Wed, 4 Oct 2023 12:36:44 +0000 (UTC)
# 296  Ei Ei <eiei.cumyeik@gmail.com>  Wed, 11 Oct 2023 12:37:42 +0000 (UTC)
# 611  Ei Ei <eiei.cumyeik@gmail.com>   Fri, 6 Oct 2023 12:36:42 +0000 (UTC)
# 615  Ei Ei <eiei.cumyeik@gmail.com>  Tue, 24 Oct 2023 13:25:42 +0000 (UTC)
# 713          eiei.cumyeik@gmail.com        Tue, 10 Oct 2023 08:26:50 -0700
# 723  Ei Ei <eiei.cumyeik@gmail.com>  Mon, 16 Oct 2023 12:36:42 +0000 (UTC)
# 770  Ei Ei <eiei.cumyeik@gmail.com>  Fri, 29 Sep 2023 12:37:42 +0000 (UTC)
#
#                                             Message_ID  \
# 10   <471494734.5942410.1698410203648@lor1-app11543...
# 86   <2044691313.32512793.1696855063092@lor1-app961...
# 100  <61716246.20695319.1697632602725@lor1-app11656...
# 233  <1908974872.14074526.1698669403468@ltx1-app555...
# 281  <1203025526.13984759.1696423004426@lor1-app528...
# 296  <1059282978.7132394.1697027862910@lor1-app5010...
# 611  <447302765.21430200.1696595802903@lor1-app4978...
# 615  <501523891.1643802.1698153942820@lor1-app11602...
# 713  <0.1.3FF.7AF.1D9FB8E30BA7C38.0@omp.e.linkedin....
# 723  <1205816484.13037586.1697459802283@lor1-app116...
# 770  <1143315258.11258761.1695991062231@lor1-app432...
#
#                                                   Body
# 10   [[Content-Type, Content-Transfer-Encoding, Con...
# 86   [[Content-Type, Content-Transfer-Encoding, Con...
# 100  [[Content-Type, Content-Transfer-Encoding, Con...
# 233  [[Content-Type, Content-Transfer-Encoding, Con...
# 281  [[Content-Type, Content-Transfer-Encoding, Con...
# 296  [[Content-Type, Content-Transfer-Encoding, Con...
# 611  [[Content-Type, Content-Transfer-Encoding, Con...
# 615  [[Content-Type, Content-Transfer-Encoding, Con...
# 713  <=21DOCTYPE html PUBLIC =22-//W3C//DTD XHTML 1...
# 723  [[Content-Type, Content-Transfer-Encoding, Con...
# 770  [[Content-Type, Content-Transfer-Encoding, Con...
